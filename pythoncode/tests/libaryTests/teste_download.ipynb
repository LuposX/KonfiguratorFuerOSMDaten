# %%
import osmnx as ox
import geopandas as gpd

# %%
df = gpd.read_file("../../data/partOfKarlsruhe.geojson")
df
# Out:
#                    name                                           geometry
# 0  Karlsruher Zoogarten  POLYGON ((8.39751 49.00125, 8.39751 48.99546, ...
# 1    Karlsruher Schloss  POLYGON ((8.40366 49.01429, 8.40366 49.01293, ...

# %%
# downlaod the data
karl = ox.geometries_from_polygon(df["geometry"][0], tags={"building": True})
karl
# Out:
#                                                                   geometry  \
# element_type osmid
# node         4728572193                           POINT (8.39939 48.99869)
# way          15526552    POLYGON ((8.40249 49.00122, 8.40249 49.00121, ...
#              15526579    POLYGON ((8.40237 49.00085, 8.40237 49.00086, ...
#              43539595    POLYGON ((8.40148 48.99863, 8.40151 48.99855, ...
#              43539597    POLYGON ((8.40313 48.99741, 8.40314 48.99739, ...
# ...                                                                    ...
#              1095324741  POLYGON ((8.40220 48.99618, 8.40219 48.99619, ...
#              1095324742  POLYGON ((8.40220 48.99618, 8.40224 48.99616, ...
# relation     4854902     POLYGON ((8.40220 49.00168, 8.40221 49.00172, ...
#              8184250     POLYGON ((8.39856 48.99901, 8.39873 48.99834, ...
#              8184251     POLYGON ((8.39801 48.99828, 8.39798 48.99859, ...
#
# ...
